# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ### Importing Dataset

# %%
df = pd.read_csv("Weather Data.csv")

# %% [markdown]
# ### Basic Exploration about data

# %%
df.head(3)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog

# %%
df.tail(3)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# 8781            4.8      99.95    Snow
# 8782            9.7      99.91    Snow
# 8783           11.3      99.89    Snow

# %% [markdown]
# ### Defining DataInfoAll

# %%
def DataInfoAll(df):
    print(f"Dataset Shape: {df.shape}")
    print("-"*125)
    summary = pd.DataFrame(df.dtypes,columns=['dtypes'])
    summary = summary.reset_index()
    summary['Name'] = summary['index']
    summary = summary[['Name','dtypes']]
    summary['Missing'] = df.isnull().sum().values    
    summary['Uniques'] = df.nunique().values
    summary['First Value'] = df.iloc[0].values
    summary['Second Value'] = df.iloc[1].values
    return summary

# %%
DataInfoAll(df)
# Out:
# Dataset Shape: (8784, 8)
# -----------------------------------------------------------------------------------------------------------------------------
#                Name   dtypes  Missing  Uniques    First Value   Second Value
# 0         Date/Time   object        0     8784  1/1/2012 0:00  1/1/2012 1:00
# 1            Temp_C  float64        0      533           -1.8           -1.8
# 2  Dew Point Temp_C  float64        0      489           -3.9           -3.7
# 3         Rel Hum_%    int64        0       83             86             87
# 4   Wind Speed_km/h    int64        0       34              4              4
# 5     Visibility_km  float64        0       24              8              8
# 6         Press_kPa  float64        0      518         101.24         101.24
# 7           Weather   object        0       50            Fog            Fog

# %%
column = df.columns
for columns in column:
    print("->",columns)
# Out:
# -> Date/Time
# -> Temp_C
# -> Dew Point Temp_C
# -> Rel Hum_%
# -> Wind Speed_km/h
# -> Visibility_km
# -> Press_kPa
# -> Weather

# %% [markdown]
# ### Unique Values

# %%
weather = df["Weather"].unique()
for weathers in weather:
    print("->",weathers)
# Out:
# -> Fog
# -> Freezing Drizzle,Fog
# -> Mostly Cloudy
# -> Cloudy
# -> Rain
# -> Rain Showers
# -> Mainly Clear
# -> Snow Showers
# -> Snow
# -> Clear
# -> Freezing Rain,Fog
# -> Freezing Rain
# -> Freezing Drizzle
# -> Rain,Snow
# -> Moderate Snow
# -> Freezing Drizzle,Snow
# -> Freezing Rain,Snow Grains
# -> Snow,Blowing Snow
# -> Freezing Fog
# -> Haze
# -> Rain,Fog
# -> Drizzle,Fog
# -> Drizzle
# -> Freezing Drizzle,Haze
# -> Freezing Rain,Haze
# -> Snow,Haze
# -> Snow,Fog
# -> Snow,Ice Pellets
# -> Rain,Haze
# -> Thunderstorms,Rain
# -> Thunderstorms,Rain Showers
# -> Thunderstorms,Heavy Rain Showers
# -> Thunderstorms,Rain Showers,Fog
# -> Thunderstorms
# -> Thunderstorms,Rain,Fog
# -> Thunderstorms,Moderate Rain Showers,Fog
# -> Rain Showers,Fog
# -> Rain Showers,Snow Showers
# -> Snow Pellets
# -> Rain,Snow,Fog
# -> Moderate Rain,Fog
# -> Freezing Rain,Ice Pellets,Fog
# -> Drizzle,Ice Pellets,Fog
# -> Drizzle,Snow
# -> Rain,Ice Pellets
# -> Drizzle,Snow,Fog
# ...

# %% [markdown]
# ### Number of unique values

# %%
df.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %% [markdown]
# ### Count number of values

# %%
df.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
df['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
# Date/Time           8784 non-null object
# Temp_C              8784 non-null float64
# Dew Point Temp_C    8784 non-null float64
# Rel Hum_%           8784 non-null int64
# Wind Speed_km/h     8784 non-null int64
# Visibility_km       8784 non-null float64
# Press_kPa           8784 non-null float64
# Weather             8784 non-null object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# ### Find unique number of wind speed

# %%
df["Wind Speed_km/h"].nunique()
# Out:
# 34

# %%
df['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %% [markdown]
# ### Findno of weather is exactly clear

# %%
df[df["Weather"]=="Clear"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
df.groupby("Weather").get_group("Clear")
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
df.groupby("Wind Speed_km/h").get_group(4).count()
# Out:
# Date/Time           474
# Temp_C              474
# Dew Point Temp_C    474
# Rel Hum_%           474
# Wind Speed_km/h     474
# Visibility_km       474
# Press_kPa           474
# Weather             474
# dtype: int64

# %%
df[df["Wind Speed_km/h"]==4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %% [markdown]
# ### Find Null Values

# %%
NaN_Checker = pd.DataFrame({"No Of Total Values": df.shape[0] , "No of NaN values": df.isnull().sum(),
                    "%age of NaN values" : round((df.isnull().sum()/ df.shape[0])*100 , 2) })
NaN_Checker.sort_values("No of NaN values" , ascending = False)
# Out:
#                   No Of Total Values  No of NaN values  %age of NaN values
# Date/Time                       8784                 0                 0.0
# Temp_C                          8784                 0                 0.0
# Dew Point Temp_C                8784                 0                 0.0
# Rel Hum_%                       8784                 0                 0.0
# Wind Speed_km/h                 8784                 0                 0.0
# Visibility_km                   8784                 0                 0.0
# Press_kPa                       8784                 0                 0.0
# Weather                         8784                 0                 0.0

# %% [markdown]
# * There is no NaN values present here

# %%
df.rename(columns={"Weather":"Weather Condition"},inplace=True)

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
df.describe().T
# Out:
#                    count        mean        std    min     25%     50%  \
# Temp_C            8784.0    8.798144  11.687883 -23.30    0.10    9.30
# Dew Point Temp_C  8784.0    2.555294  10.883072 -28.50   -5.90    3.30
# Rel Hum_%         8784.0   67.431694  16.918881  18.00   56.00   68.00
# Wind Speed_km/h   8784.0   14.945469   8.688696   0.00    9.00   13.00
# Visibility_km     8784.0   27.664447  12.622688   0.20   24.10   25.00
# Press_kPa         8784.0  101.051623   0.844005  97.52  100.56  101.07
#
#                      75%     max
# Temp_C             18.80   33.00
# Dew Point Temp_C   11.80   24.40
# Rel Hum_%          81.00  100.00
# Wind Speed_km/h    20.00   83.00
# Visibility_km      25.00   48.30
# Press_kPa         101.59  103.65

# %%
df.rename(columns={"Rel Hum_%":"Humidity"},inplace=True)

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Humidity  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9        86                4
# 1  1/1/2012 1:00    -1.8              -3.7        87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %% [markdown]
# ### Find all instance when snow

# %%
df[df["Weather Condition"]=="Snow"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Humidity  Wind Speed_km/h  \
# 55       1/3/2012 7:00   -14.0             -19.5        63               19
# 84      1/4/2012 12:00   -13.7             -21.7        51               11
# 86      1/4/2012 14:00   -11.3             -19.0        53                7
# 87      1/4/2012 15:00   -10.2             -16.3        61               11
# 88      1/4/2012 16:00    -9.4             -15.5        61               13
# ...                ...     ...               ...       ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7        81               30
# 8780  12/31/2012 20:00     0.2              -2.4        83               24
# 8781  12/31/2012 21:00    -0.5              -1.5        93               28
# 8782  12/31/2012 22:00    -0.2              -1.8        89               28
# 8783  12/31/2012 23:00     0.0              -2.1        86               30
#
#       Visibility_km  Press_kPa Weather Condition
# ...

# %%
df[df["Weather Condition"].str.contains("Snow")]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Humidity  Wind Speed_km/h  \
# 41      1/2/2012 17:00    -2.1              -9.5        57               22
# 44      1/2/2012 20:00    -5.6             -13.4        54               24
# 45      1/2/2012 21:00    -5.8             -12.8        58               26
# 47      1/2/2012 23:00    -7.4             -14.1        59               17
# 48       1/3/2012 0:00    -9.0             -16.0        57               28
# ...                ...     ...               ...       ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7        81               30
# 8780  12/31/2012 20:00     0.2              -2.4        83               24
# 8781  12/31/2012 21:00    -0.5              -1.5        93               28
# 8782  12/31/2012 22:00    -0.2              -1.8        89               28
# 8783  12/31/2012 23:00     0.0              -2.1        86               30
#
#       Visibility_km  Press_kPa Weather Condition
# ...

# %%
df[df["Weather Condition"].str.contains("Snow")]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Humidity  Wind Speed_km/h  \
# 41      1/2/2012 17:00    -2.1              -9.5        57               22
# 44      1/2/2012 20:00    -5.6             -13.4        54               24
# 45      1/2/2012 21:00    -5.8             -12.8        58               26
# 47      1/2/2012 23:00    -7.4             -14.1        59               17
# 48       1/3/2012 0:00    -9.0             -16.0        57               28
# ...                ...     ...               ...       ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7        81               30
# 8780  12/31/2012 20:00     0.2              -2.4        83               24
# 8781  12/31/2012 21:00    -0.5              -1.5        93               28
# 8782  12/31/2012 22:00    -0.2              -1.8        89               28
# 8783  12/31/2012 23:00     0.0              -2.1        86               30
#
#       Visibility_km  Press_kPa Weather Condition
# ...

# %%
df[(df["Wind Speed_km/h"]>24)&(df["Visibility_km"]==25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Humidity  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0        79               30
# 24       1/2/2012 0:00     5.2               1.5        77               35
# 25       1/2/2012 1:00     4.6               0.0        72               39
# 26       1/2/2012 2:00     3.9              -0.9        71               32
# 27       1/2/2012 3:00     3.7              -1.5        69               33
# ...                ...     ...               ...       ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0        76               26
# 8753  12/30/2012 17:00   -12.1             -15.8        74               28
# 8755  12/30/2012 19:00   -13.4             -16.5        77               26
# 8759  12/30/2012 23:00   -12.1             -15.1        78               28
# 8760   12/31/2012 0:00   -11.1             -14.4        77               26
#
#       Visibility_km  Press_kPa Weather Condition
# ...

# %%
df.groupby("Weather Condition").mean()
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather Condition
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %%
df.groupby("Weather Condition").min()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather Condition
# Clear                                      1/11/2012 1:00   -23.3
# Cloudy                                     1/1/2012 17:00   -21.4
# Drizzle                                   1/23/2012 21:00     1.1
# Drizzle,Fog                               1/23/2012 20:00     0.0
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/17/2012 15:00     0.9
# Drizzle,Snow,Fog                         12/18/2012 21:00     0.3
# Fog                                         1/1/2012 0:00   -16.0
# Freezing Drizzle                          1/13/2012 10:00    -9.0
# Freezing Drizzle,Fog                        1/1/2012 2:00    -6.4
# Freezing Drizzle,Haze                      2/1/2012 11:00    -5.8
# Freezing Drizzle,Snow                      1/13/2012 3:00    -8.3
# Freezing Fog                               1/22/2012 6:00   -19.0
# ...

# %%
df[df["Weather Condition"]=="Fog"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Humidity  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9        86                4
# 1        1/1/2012 1:00    -1.8              -3.7        87                4
# 4        1/1/2012 4:00    -1.5              -3.3        88                7
# 5        1/1/2012 5:00    -1.4              -3.3        87                9
# 6        1/1/2012 6:00    -1.5              -3.1        89                7
# ...                ...     ...               ...       ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2        90                6
# 8717   12/29/2012 5:00   -14.8             -15.9        91                4
# 8718   12/29/2012 6:00   -13.8             -15.3        88                4
# 8719   12/29/2012 7:00   -14.8             -16.4        88                7
# 8722  12/29/2012 10:00   -12.0             -13.3        90                7
#
#       Visibility_km  Press_kPa Weather Condition
# ...

# %%
df[(df['Weather Condition'] == 'Clear') | (df['Visibility_km'] > 40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Humidity  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8        50               24
# 106     1/5/2012 10:00    -6.0             -10.0        73               17
# 107     1/5/2012 11:00    -5.6             -10.2        70               22
# 108     1/5/2012 12:00    -4.7              -9.6        69               20
# 109     1/5/2012 13:00    -4.4              -9.7        66               26
# ...                ...     ...               ...       ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2        73               37
# 8750  12/30/2012 14:00   -11.8             -16.1        70               37
# 8751  12/30/2012 15:00   -11.3             -15.6        70               32
# 8752  12/30/2012 16:00   -11.4             -15.5        72               26
# 8756  12/30/2012 20:00   -13.8             -16.5        80               24
#
#       Visibility_km  Press_kPa Weather Condition
# ...

# %% [markdown]
# ### Weather is Clear and 'Relative humidity' is Greater than 50
# ### or
# ### visibility is above 40

# %%
df[(df["Weather Condition"]=="Clear")&(df["Humidity"]>50)|(df["Visibility_km"]>40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Humidity  Wind Speed_km/h  \
# 106     1/5/2012 10:00    -6.0             -10.0        73               17
# 107     1/5/2012 11:00    -5.6             -10.2        70               22
# 108     1/5/2012 12:00    -4.7              -9.6        69               20
# 109     1/5/2012 13:00    -4.4              -9.7        66               26
# 110     1/5/2012 14:00    -5.1             -10.7        65               22
# ...                ...     ...               ...       ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2        73               37
# 8750  12/30/2012 14:00   -11.8             -16.1        70               37
# 8751  12/30/2012 15:00   -11.3             -15.6        70               32
# 8752  12/30/2012 16:00   -11.4             -15.5        72               26
# 8756  12/30/2012 20:00   -13.8             -16.5        80               24
#
#       Visibility_km  Press_kPa Weather Condition
# ...

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['Humidity'], bins=20, color='green', alpha=0.7)
plt.xlabel('Humidity')
plt.ylabel('Frequency')
plt.title('Humidity Distribution')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['Wind Speed_km/h'], color='yellow')
plt.xlabel('Wind Speed (km/h)')
plt.title('Wind Speed Distribution')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Temp_C', y='Dew Point Temp_C', data=df, color='purple')
plt.xlabel('Temperature (°C)')
plt.ylabel('Dew Point Temperature (°C)')
plt.title('Temperature vs. Dew Point Temperature')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Weather Condition', data=df, palette='viridis')
plt.xlabel('Weather Condition')
plt.ylabel('Count')
plt.title('Weather Condition Counts')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Making new column Month and year

# %%
df['Date/Time'] = pd.to_datetime(df['Date/Time'])

# %%
df['Month'] = df['Date/Time'].dt.strftime('%B')
df["Year"]=df["Date/Time"].dt.year

# %%
df.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Humidity  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9        86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7        87                4
#
#    Visibility_km  Press_kPa Weather Condition    Month  Year
# 0            8.0     101.24               Fog  January  2012
# 1            8.0     101.24               Fog  January  2012

# %%
df["Year"].unique()
# Out:
# array([2012], dtype=int64)

# %%
plt.figure(figsize=(12, 10))
sns.barplot(x="Humidity",y="Month",data=df,palette="mako")
plt.grid()
plt.show()
